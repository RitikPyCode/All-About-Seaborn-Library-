# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=pd.read_csv(r"C:\Users\Ritik Kumar Tiwari\Desktop\datasets_19_420_Iris.csv")
sns.relplot(x="SepalLengthCm", y="PetalLengthCm", data=a)
plt.show()

# %%
a=pd.read_csv(r"C:\Users\Ritik Kumar Tiwari\Desktop\datasets_19_420_Iris.csv")
plt.show()

# %%
a.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.relplot(x="SepalLengthCm", y="PetalLengthCm",hue="Species", data=a)
plt.show()

# %%
sns.relplot(x="SepalLengthCm", y="PetalLengthCm",hue="Species", kind="line", data=a)

# %%
sns.relplot(x="SepalLengthCm", y="PetalLengthCm",hue="Id",  data=a)

# %%
a.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sns.relplot(x="PetalWidthCm", y="PetalLengthCm", kind="line",  data=a)

# %%
sns.catplot(x="Id", y="Species", data=a)

# %%
sns.catplot(x="Id", y="Species", kind="violin", data=a)

# %%
sns.catplot(x="Id", y="Species", kind="boxen", data=a)

# %%
from scipy import stats

# %%
c=np.random.normal(loc=7, size=200, scale=5)
sns.distplot(c)

# %%
 a.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
b=sns.FacetGrid(a, col="Species")
b.map(plt.hist, "SepalWidthCm")

# %%
b=sns.PairGrid(a)
b.map(plt.scatter)

# %%
sns.set(style="darkgrid")
c=sns.PairGrid(a)
c.map(plt.scatter)

# %%
sns.set(style="white")
c=sns.PairGrid(a)
c.map(plt.scatter)

# %%
sns.set(style="white", color_codes=True)
sns.boxplot(x="Species", y="Id", data=a)

# %%
sns.set(style="darkgrid", color_codes=True)
sns.boxplot(x="Species", y="Id", data=a)

# %%
sns.set(style="white", color_codes=True)
sns.boxplot(x="Species", y="Id", data=a)
sns.despine(offset=10, trim=True)

# %%
sns.set(style="ticks", color_codes=True)
sns.boxplot(x="Species", y="Id", data=a)
sns.despine(offset=10, trim=True)

# %%
sns.set(style="darkgrid", color_codes=True)
sns.boxplot(x="Species", y="Id", data=a)
sns.despine(offset=10, trim=True)

# %%
sns.set(style="white", color_codes=True)
sns.boxplot(x="Species", y="Id", data=a)
sns.despine(offset=10, trim=True)
c=sns.color_palette()
sns.palplot(c)

# %%
c=sns.color_palette()
sns.palplot(c)
